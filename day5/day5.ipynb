# %%
## Load Data ##
data = open('day5.txt').readlines()
# Out:
# 500

# %%
### Part 1 ###


def formatData():
    coords = []
    for line in data:
        entry = line.replace(" ","").replace("\n","").replace("->",",").split(",")
        for i in range(len(entry)):
            entry[i] = int(entry[i])
        coords.append(entry)
        
    return coords

def mapVents():
    coords = formatData()

    nx = max(max([(c[0], c[2])for c in coords])) + 1
    ny = max(max([(c[1], c[3])for c in coords])) + 1

    board = [[0 for i in range(nx)] for j in range(ny)]

    for x1, y1, x2, y2 in coords:
        xmin, dx = min(x1, x2), abs(x2 - x1)
        ymin, dy = min(y1, y2), abs(y2 - y1)
        if x1 == x2:
            for i in range(dy + 1):
                board[i + ymin][x1] += 1
        elif y1 == y2:
            for i in range(dx + 1):
                board[y1][i + xmin] += 1


    return sum([1 for line in board for num in line if num > 1])

print(mapVents())
# Out:
# 5698

# %%
### Part 2 ###


def mapVents():
    coords = formatData()

    nx = max(max([(c[0], c[2])for c in coords])) + 1
    ny = max(max([(c[1], c[3])for c in coords])) + 1

    board = [[0 for i in range(nx)] for j in range(ny)]

    for x1, y1, x2, y2 in coords:
        xmin, dx = min(x1, x2), abs(x2 - x1)
        ymin, dy = min(y1, y2), abs(y2 - y1)
        if x1 == x2:
            for i in range(dy + 1):
                board[i + ymin][x1] += 1
        elif y1 == y2:
            for i in range(dx + 1):
                board[y1][i + xmin] += 1
        else:
            for i in range(max(dx,dy)+1):
                xdir = 1 if x1 < x2 else -1
                ydir = 1 if y1 < y2 else -1
                board[ydir*i + y1][xdir*i + x1] += 1

    return sum([1 for line in board for num in line if num > 1])

print(mapVents())
# Out:
# 15463

# %%
### Visualisation ###
import sys, pygame
from pygame import rect, Rect

data = open('day5.txt').readlines()

#dimensions
size = width, height = 1000,1000

#colors
white = 255,255,255
black = 0,0,0
grey = 112, 112, 112
gold = 148, 124, 0
yellow = 255, 214, 0
green = 38, 189, 0
red =255, 0, 0

#constants
tableSize = 5
startY = 20
startX = 15
moveX = 100
moveRowY = 100
startDataX = 1020
counterStart = 1075



### ------------ Solving Functions ------------ ### 
def formatData():
    coords = []
    for line in data:
        entry = line.replace(" ","").replace("\n","").replace("->",",").split(",")
        for i in range(len(entry)):
            entry[i] = int(entry[i])
        coords.append(entry)
        
    return coords

def mapVents():
    board = [[0 for i in range(1000)] for j in range(1000)]

    return(board)

def updateVents(counter, board, coords):
    for i in range(5):
        x1, y1, x2, y2 = coords[counter+i]
        print(x1,y1,x2,y2)

        xmin, dx = min(x1, x2), abs(x2 - x1)
        ymin, dy = min(y1, y2), abs(y2 - y1)
        if x1 == x2:
            for i in range(dy + 1):
                board[i + ymin][x1] += 1
        elif y1 == y2:
            for i in range(dx + 1):
                board[y1][i + xmin] += 1
        else:
            for i in range(max(dx,dy)+1):
                xdir = 1 if x1 < x2 else -1
                ydir = 1 if y1 < y2 else -1
                board[ydir*i + y1][xdir*i + x1] += 1
    
    return(board)
            

### ------------ End Solving Functions ------------ ### 

    
def drawArt(screen,ind):
    font = pygame.font.Font('Minecraft.ttf', 20)
    if(ind % 2 == 0):
        text = font.render("Vent OS|", True, white, black)
    else:
        text = font.render("Vent OS", True, white, black)
    textRect = text.get_rect()
    textRect.center = (width/2, height/2)
    screen.blit(text, textRect)
                       
            
    
def drawVents(screen,data):
    x = startX
    y = startY
    for y in range(len(data)):
        for x in range(len(data[0])):
            if(data[y][x] >= 2):
                pygame.draw.rect(screen, red,(x,y,1,1))
            elif(data[y][x] == 1):
                pygame.draw.rect(screen, grey,(x,y,1,1))
    

        
def visualisation():
    pygame.init()
    screen = pygame.display.set_mode(size)
    pygame.display.set_caption('Day5 Visualiser')
    
    coords = formatData()
    board = mapVents()
    
    updateSpeed = 500
    counter = -6
    
    while True:
        for event in pygame.event.get():
            if event.type == pygame.QUIT: 
                pygame.quit()
                return
        
        if counter < 0: #Starting Screen
            screen.fill(black)
            drawArt(screen,counter)
            counter += 1
            
        elif counter < 500:  #VIsualization
            updateSpeed = 1
            
            board = updateVents(counter,board,coords)
            counter += 5

            screen.fill(black)
            drawVents(screen,board)  
            
        pygame.display.update()
        pygame.time.wait(updateSpeed)
        
        

            
        
        
visualisation()
# Out:
# 692 826 692 915
# 914 338 524 728
# 77 505 77 912
# 31 484 250 703
# 29 241 313 241
# 381 70 381 121
# 699 595 641 595
# 69 989 517 989
# 99 755 99 687
# 205 77 844 77
# 754 705 754 720
# 739 884 739 737
# 504 463 854 113
# 85 386 416 717
# 39 456 449 46
# 900 469 900 462
# 137 680 137 713
# 797 792 264 792
# 814 750 86 22
# 252 644 491 644
# 932 162 932 615
# 42 71 464 71
# 924 685 755 685
# 729 610 729 391
# 921 369 921 649
# 833 241 101 241
# 822 459 507 459
# 739 74 807 142
# 573 850 573 619
# 888 60 888 592
# 133 272 339 66
# 882 662 665 662
# 572 499 959 112
# 631 173 404 173
# 886 730 470 730
# 116 435 980 435
# 795 299 886 390
# 321 464 321 785
# 210 477 210 880
# 215 191 59 347
# 921 749 363 191
# 598 962 924 636
# 105 70 105 411
# 617 221 617 958
# 383 403 383 208
# 763 129 118 129
# 236 185 236 57
# 608 592 950 250
# 872 54 761 54
# 542 49 542 195
# 943 104 59 988
# 800 709 800 416
# 432 628 947 113
# 396 169 61 169
# 982 694 611 323
# 500 381 803 381
# 843 803 101 61
# ...
